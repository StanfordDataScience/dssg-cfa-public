# %%
import os
import json
import requests


from helpers import check_gazette_filenames as cf
from helpersimport json_extraction as je
from helpers import write_urls as wu 
from helpers import dest_fn_from_url as df

# %% [markdown]
# The below will prompt you to rename files to correctly reflect their contents. Naming issues are described in the "check_gazette_filenames" file
#
# "check_filenames" will print information and instructions. Manually check that output is reasonable; approve or deny rename request. We recommend cross-checking suggested renames with the gazettes in the original database.
#
# Note that, as the `rename_gazettes` code stands, gazettes that are incorrectly labelled as special issues are **automatically renamed** (without prompting). Change this if you would like to be more cautious.
#
# * The functions for checking special issues are extremely reliable.
# * The dated functions are relatively reliable, but occasionally misidentify dates. At minimum, ensure that the dates are real dates.
# * However, the volume/issue numbering checks return errors sometimes. We'd recommend manually confirming these if the issue or volume numbering only differs by one character (e.g., "cii" vs. "ci").

# %%
def in_date_range(f, yr_start, yr_end): 
    '''
    Filter for files dated beginning at yr_start, up to but not including yr_end
    '''
    for yr in range(yr_start, yr_end + 1): 
        if str(yr) in f: 
            return True
    return False

filepath = "/home/dssg-cfa/ke-gazettes/"
filename_list = [f for f in os.listdir(filepath) if in_date_range(f, 2000, 2009)]

for fn in filename_list:
    with open(filepath + fn) as file:
        gazette_data = json.load(file)
    cf.check_filename(fn, gazette_data)

# %%
'''
Note: 
- By this weekend (8/22), there will be additional code for associating
files and filenames in our databases with unique identifiers in the Connected Africa
and Gazeti databases. 
- This will be necessary for facilitating a data transfer. 
'''
