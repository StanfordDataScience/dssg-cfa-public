# %%
# -------------------------------------------------
#
# This notebook is a walkthrough of the network visualization tool, Gephi. 
# Although our team used this tool, one can use their prefered tool to visualize the nodes and edges.
#
# -------------------------------------------------

# %% [markdown]
# ## Introduction
#
# One can follow [this tutorial](http://www.briansarnacki.com/gephi-tutorial/): http://www.briansarnacki.com/gephi-tutorial/ for steps to install Gephi on one's local computer and to get started. This process takes less than 10 minutes.
#
# ## Load the Data
#
# After the installation process is complete, one can import the edges and nodes list that is available in the `network_outputs` folder in this repo. Note, these outputs are only from one gazette and they are available here for reference. The complete output from 151 gazettes with over 6000 nodes and 3 million edges is too large to be uploaded to this GitHub page but it will be transferred to partners.
#
#
# ## Start Visualization
#
# After importing the nodes and edges, the following visualization will appear in the graph folder. Click on `Graph` (#1 in the image below) to see the visualization and `Layout` (#2 in the image below) to try different layouts and choose the one that best suits the data at hand. One can also change the coloring and size as desired using the options under the `Appearance` tab.

# %%
from PIL import Image
import os

DIR_1 = '/home/dssg-cfa/notebooks/dssg-cfa-public/D_build_network/supporting_images/'
Image.open(DIR_1 + 'gephi_output_stage_1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1214 at 0x7F137AD313D0>

# %% [markdown]
# ## Modify Visualization
#
# One can click on the pop up arrow (labelled as #3). This tab lets the user modify the label on the edges and nodes. Mark the "Hide non-selected" tab to only display the label of the node the user is hovering over. [Here is](https://www.youtube.com/watch?v=oelnGSgMcgE) a short further youtube discription of this label option.

# %%
Image.open(DIR_1 + 'gephi_output_stage_2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2130x1286 at 0x7F137AC4CAD0>

# %%
## The END
